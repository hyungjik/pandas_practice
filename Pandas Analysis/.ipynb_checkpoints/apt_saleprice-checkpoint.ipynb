# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import re
from plotnine import *

# %%
# %pwd
# Out:
# 'C:\\pandas_practice\\Pandas Analysis'

# %%
pre_sale = pd.read_csv("recent_price.csv", encoding='euc-kr')
pre_sale.shape
# Out:
# (3060, 5)

# %%
pre_sale.head()
# Out:
#   지역명               규모구분    연도   월 분양가격(㎡)
# 0  서울         전용면적 60㎡이하  2015  10    5652
# 1  서울   전용면적 60㎡초과 85㎡이하  2015  10    5882
# 2  서울  전용면적 85㎡초과 102㎡이하  2015  10    5721
# 3  서울        전용면적 102㎡초과  2015  10    5879
# 4  인천         전용면적 60㎡이하  2015  10    3488

# %%
pre_sale.tail()
# Out:
#      지역명               규모구분    연도  월 분양가격(㎡)
# 3055  경남        전용면적 102㎡초과  2019  6    4303
# 3056  제주         전용면적 60㎡이하  2019  6    3804
# 3057  제주   전용면적 60㎡초과 85㎡이하  2019  6    3791
# 3058  제주  전용면적 85㎡초과 102㎡이하  2019  6    3226
# 3059  제주        전용면적 102㎡초과  2019  6    3269

# %%
pre_sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3060 entries, 0 to 3059
# Data columns (total 5 columns):
# 지역명        3060 non-null object
# 규모구분       3060 non-null object
# 연도         3060 non-null int64
# 월          3060 non-null int64
# 분양가격(㎡)    2841 non-null object
# dtypes: int64(2), object(3)
# memory usage: 119.6+ KB

# %%
pre_sale.dtypes
# Out:
# 지역명        object
# 규모구분       object
# 연도          int64
# 월           int64
# 분양가격(㎡)    object
# dtype: object

# %%
pre_sale.isnull().sum()
# Out:
# 지역명          0
# 규모구분         0
# 연도           0
# 월            0
# 분양가격(㎡)    219
# dtype: int64

# %%
# 결측치 보기
import missingno as msno
msno.matrix(pre_sale, figsize=(18,6))

# %%
pre_sale['연도'] = pre_sale['연도'].astype(str)
pre_sale['월'] = pre_sale['월'].astype(str)

# %%
pre_sale_price = pre_sale['분양가격(㎡)']

# %%
# 분양가격의 타입을 숫자로 변경해준다
pre_sale['분양가격'] = pd.to_numeric(pre_sale_price, errors='coerce')
# 평당 분양가격을 구하자
pre_sale['평당분양가격'] = pre_sale['분양가격'] * 3.3

# %%
pre_sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3060 entries, 0 to 3059
# Data columns (total 7 columns):
# 지역명        3060 non-null object
# 규모구분       3060 non-null object
# 연도         3060 non-null object
# 월          3060 non-null object
# 분양가격(㎡)    2841 non-null object
# 분양가격       2758 non-null float64
# 평당분양가격     2758 non-null float64
# dtypes: float64(2), object(5)
# memory usage: 167.4+ KB

# %%
pre_sale.dtypes
# Out:
# 지역명         object
# 규모구분        object
# 연도          object
# 월           object
# 분양가격(㎡)     object
# 분양가격       float64
# 평당분양가격     float64
# dtype: object

# %%
# 결측치 확인
pre_sale.isnull().sum()
# 공백을 인식하였으나 수치로 변환할떄 null로 집계됨
# Out:
# 지역명          0
# 규모구분         0
# 연도           0
# 월            0
# 분양가격(㎡)    219
# 분양가격       302
# 평당분양가격     302
# dtype: int64

# %%
pre_sale.describe()
# Out:
#                분양가격        평당분양가격
# count   2758.000000   2758.000000
# mean    3193.791878  10539.513198
# std     1194.148522   3940.690123
# min     1868.000000   6164.400000
# 25%     2432.250000   8026.425000
# 50%     2840.500000   9373.650000
# 75%     3478.000000  11477.400000
# max    12728.000000  42002.400000

# %%
pre_sale.describe(include=[np.object])
# 월과 가격도 object 형태로 바꿨기때문에 확인가능함
# Out:
#          지역명               규모구분    연도     월 분양가격(㎡)
# count   3060               3060  3060  3060    2841
# unique    17                  4     5    12    1293
# top       전북  전용면적 85㎡초과 102㎡이하  2017     2
# freq     180                765   816   272      16

# %%
pre_sale_2017 = pre_sale.loc[pre_sale['연도'] == '2017']  # object 타입이므로 '' 붙여줌ㅋ
pre_sale_2017.shape
# Out:
# (816, 7)

# %%
pre_sale['규모구분'].value_counts()
# Out:
# 전용면적 85㎡초과 102㎡이하    765
# 전용면적 60㎡초과 85㎡이하     765
# 전용면적 60㎡이하           765
# 전용면적 102㎡초과          765
# Name: 규모구분, dtype: int64

# %%
pre_sale['지역명'].value_counts()
# Out:
# 전북    180
# 대구    180
# 충북    180
# 충남    180
# 전남    180
# 인천    180
# 경북    180
# 대전    180
# 부산    180
# 경남    180
# 경기    180
# 광주    180
# 서울    180
# 세종    180
# 제주    180
# 울산    180
# 강원    180
# Name: 지역명, dtype: int64

# %% [markdown]
# ### groupby 와 pivot_table 활용하기

# %%
pd.options.display.float_format = '{:,.0f}'.format
# describe는 수치형을 기본으로 표현함 : 분양가격과 평당분양가격만 수치형 데이터임
pre_sale.groupby(pre_sale['연도']).describe().T  # describe를 Tranpose해서 보기
# Out:
# 연도             2015   2016   2017   2018   2019
# 분양가격   count    192    780    712    716    358
#        mean   2,814  2,965  3,176  3,353  3,613
#        std      990  1,092  1,125  1,211  1,418
#        min    1,868  1,900  1,983  2,076  2,149
#        25%    2,252  2,312  2,383  2,593  2,657
#        50%    2,557  2,672  2,855  2,946  3,226
#        75%    3,003  3,153  3,470  3,705  4,066
#        max    7,092  8,096  7,887  8,098 12,728
# 평당분양가격 count    192    780    712    716    358
#        mean   9,285  9,785 10,481 11,065 11,922
#        std    3,267  3,603  3,712  3,996  4,680
#        min    6,164  6,270  6,544  6,851  7,092
#        25%    7,433  7,629  7,863  8,556  8,768
#        50%    8,438  8,818  9,422  9,722 10,646
#        75%    9,909 10,406 11,450 12,226 13,416
#        max   23,404 26,717 26,027 26,723 42,002

# %%
pre_sale.groupby(pre_sale['연도']).describe()
# Out:
#       분양가격                                            평당분양가격               \
#      count  mean   std   min   25%   50%   75%    max  count   mean   std
# 연도
# 2015   192 2,814   990 1,868 2,252 2,557 3,003  7,092    192  9,285 3,267
# 2016   780 2,965 1,092 1,900 2,312 2,672 3,153  8,096    780  9,785 3,603
# 2017   712 3,176 1,125 1,983 2,383 2,855 3,470  7,887    712 10,481 3,712
# 2018   716 3,353 1,211 2,076 2,593 2,946 3,705  8,098    716 11,065 3,996
# 2019   358 3,613 1,418 2,149 2,657 3,226 4,066 12,728    358 11,922 4,680
#
#
#        min   25%    50%    75%    max
# 연도
# 2015 6,164 7,433  8,438  9,909 23,404
# 2016 6,270 7,629  8,818 10,406 26,717
# 2017 6,544 7,863  9,422 11,450 26,027
# 2018 6,851 8,556  9,722 12,226 26,723
# 2019 7,092 8,768 10,646 13,416 42,002

# %% [markdown]
# ### 규모별 전국 평균 분양가격

# %%
pre_sale.pivot_table('평당분양가격', '규모구분', '연도')  # values, index, columns 순서대로
# Out:
# 연도                 2015   2016   2017   2018   2019
# 규모구분
# 전용면적 102㎡초과       9,837 10,389 11,334 11,446 12,879
# 전용면적 60㎡이하        8,952  9,399 10,246 10,844 11,272
# 전용면적 60㎡초과 85㎡이하  8,892  9,296  9,825 10,651 11,514
# 전용면적 85㎡초과 102㎡이하 9,519 10,122 10,540 11,442 12,033

# %% [markdown]
# ### 전국 분양가 변동금액

# %%
# 규모구분에서 60m2이하로 되어있는 데이터만 가져온다
region_year_small = pre_sale.loc[pre_sale['규모구분'] == '전용면적 60㎡이하']
# reset_index : 두개의 row로 구분된 테이블에서 구분을 삭제하기 위해서
region_year = region_year_small.pivot_table('평당분양가격', '지역명', '연도').reset_index()
region_year
# Out:
# 연도 지역명   2015   2016   2017   2018   2019
# 0   강원  7,557  7,044  7,089  7,693  8,366
# 1   경기 10,448 11,744 12,381 14,397 14,490
# 2   경남  7,391  7,991  8,499  9,266  9,549
# 3   경북  7,251  7,213  7,900  8,264  8,181
# 4   광주  7,589  8,354  8,559  9,548 10,614
# 5   대구  9,239 10,930 11,852 12,141 13,221
# 6   대전  8,530  8,736  9,253  8,282 11,002
# 7   부산  9,771  9,916 10,849 12,385 12,587
# 8   서울 20,122 21,744 21,897 23,395 25,896
# 9   세종  8,520  8,878  9,156 10,111 10,111
# 10  울산  8,349  8,641  9,538    nan    nan
# 11  인천 11,158 10,430 10,784 11,510 11,713
# 12  전남  6,597  6,632  7,202  7,403  7,364
# 13  전북  6,799  6,430  7,663  8,392  8,358
# 14  제주    nan 11,231 15,750 16,623 12,553
# 15  충남  7,544  7,706  7,781  8,056  8,364
# 16  충북  6,359  6,618  7,103  7,575  7,173

# %%
region_year['변동액'] = (region_year['2018'] - region_year['2015']) # astype(int) int로 반환
region_year['변동액'].dropna().astype(int)  # nan은 int로 바꿀수 없어서 na 제거한 것만 int화
max_delta_price = np.max(region_year['변동액'])*1000
min_delta_price = np.min(region_year['변동액'])*1000
mean_delta_price = np.mean(region_year['변동액'])*1000

print("15년부터 18년까지 변동액이 가장 큰 곳은 경기 : 평당 {:,.0f}원".format(max_delta_price))
print("15년부터 18년까지 변동액이 가장 작은 곳은 대구 : 평당 {:,.0f}원".format(min_delta_price))
print("15년부터 18년까지 평균 변동액 : 평당 {:,.0f}원".format(mean_delta_price))

region_year
# Out:
# 15년부터 18년까지 변동액이 가장 큰 곳은 경기 : 평당 3,948,725원
# 15년부터 18년까지 변동액이 가장 작은 곳은 대구 : 평당 -248,100원
# 15년부터 18년까지 평균 변동액 : 평당 1,569,440원
# 연도 지역명   2015   2016   2017   2018   2019   변동액
# 0   강원  7,557  7,044  7,089  7,693  8,366   136
# 1   경기 10,448 11,744 12,381 14,397 14,490 3,949
# 2   경남  7,391  7,991  8,499  9,266  9,549 1,875
# 3   경북  7,251  7,213  7,900  8,264  8,181 1,013
# 4   광주  7,589  8,354  8,559  9,548 10,614 1,959
# 5   대구  9,239 10,930 11,852 12,141 13,221 2,902
# 6   대전  8,530  8,736  9,253  8,282 11,002  -248
# 7   부산  9,771  9,916 10,849 12,385 12,587 2,614
# 8   서울 20,122 21,744 21,897 23,395 25,896 3,273
# 9   세종  8,520  8,878  9,156 10,111 10,111 1,592
# 10  울산  8,349  8,641  9,538    nan    nan   nan
# 11  인천 11,158 10,430 10,784 11,510 11,713   351
# 12  전남  6,597  6,632  7,202  7,403  7,364   806
# 13  전북  6,799  6,430  7,663  8,392  8,358 1,593
# 14  제주    nan 11,231 15,750 16,623 12,553   nan
# 15  충남  7,544  7,706  7,781  8,056  8,364   512
# ...

# %% [markdown]
# ## 연도별 연동 그래프

# %%
import seaborn as sns
sns.set_style("whitegrid")

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')

# %% [markdown]
# ## Seaborn 으로 막대그래프 그리기

# %%
plt.figure(figsize=(20,8))
plt.title('2015년~2018년 신규 민간 아파트 분양가격')
sns.barplot(data=region_year_small, x='지역명', y='평당분양가격', hue='연도')

# %% [markdown]
# ## Pandas로 막대그래프 그리기

# %%
df_year_region = pd.pivot_table(region_year_small, index=['지역명'], columns='연도', values='평당분양가격')
df_year_region
# Out:
# 연도    2015   2016   2017   2018   2019
# 지역명
# 강원   7,557  7,044  7,089  7,693  8,366
# 경기  10,448 11,744 12,381 14,397 14,490
# 경남   7,391  7,991  8,499  9,266  9,549
# 경북   7,251  7,213  7,900  8,264  8,181
# 광주   7,589  8,354  8,559  9,548 10,614
# 대구   9,239 10,930 11,852 12,141 13,221
# 대전   8,530  8,736  9,253  8,282 11,002
# 부산   9,771  9,916 10,849 12,385 12,587
# 서울  20,122 21,744 21,897 23,395 25,896
# 세종   8,520  8,878  9,156 10,111 10,111
# 울산   8,349  8,641  9,538    nan    nan
# 인천  11,158 10,430 10,784 11,510 11,713
# 전남   6,597  6,632  7,202  7,403  7,364
# 전북   6,799  6,430  7,663  8,392  8,358
# 제주     nan 11,231 15,750 16,623 12,553
# 충남   7,544  7,706  7,781  8,056  8,364
# 충북   6,359  6,618  7,103  7,575  7,173

# %%
df_year_region.columns
# Out:
# Index(['2015', '2016', '2017', '2018', '2019'], dtype='object', name='연도')

# %%
df_year_region.plot.bar(figsize=(24,8), grid=True, fontsize=20, rot=0, title='지역, 연도별 평당 평균 분양가')  # rot=0은 글자 가로로

# %% [markdown]
# ### 규모별

# %%
plt.figure(figsize=(20,8))
sns.barplot(data=pre_sale, x='지역명', y='평당분양가격', hue='규모구분')

# %% [markdown]
# ## -지역별 평당 분양가격 합계

# %%
pre_sale_size = pre_sale.pivot_table(values='평당분양가격', index='지역명', columns='규모구분')
pre_sale_size.sample(5)
# Out:
# 규모구분  전용면적 102㎡초과  전용면적 60㎡이하  전용면적 60㎡초과 85㎡이하  전용면적 85㎡초과 102㎡이하
# 지역명
# 경남          9,922       8,637             8,422              9,931
# 대전         14,883       8,798             9,471              9,037
# 충북          8,174       7,058             7,224              8,363
# 제주         10,324      14,195            10,320             10,709
# 울산          9,974       8,965            10,563              8,861

# %%
pre_sale_size.plot.bar()

# %%
pre_sale_size.plot.bar(title='지역, 규모구분 별 평당 평균 분양가', figsize=(20,8), grid=True, fontsize=20, rot=0)

# %%
pre_sale[(pre_sale['지역명'] == '대전') & (pre_sale['규모구분'] == '전용면적 102㎡초과')]
# Out:
#      지역명         규모구분    연도   월 분양가격(㎡)  분양가격  평당분양가격
# 27    대전  전용면적 102㎡초과  2015  10           nan     nan
# 95    대전  전용면적 102㎡초과  2015  11           nan     nan
# 163   대전  전용면적 102㎡초과  2015  12           nan     nan
# 231   대전  전용면적 102㎡초과  2016   1           nan     nan
# 299   대전  전용면적 102㎡초과  2016   2     NaN   nan     nan
# 367   대전  전용면적 102㎡초과  2016   3     NaN   nan     nan
# 435   대전  전용면적 102㎡초과  2016   4     NaN   nan     nan
# 503   대전  전용면적 102㎡초과  2016   5     NaN   nan     nan
# 571   대전  전용면적 102㎡초과  2016   6     NaN   nan     nan
# 639   대전  전용면적 102㎡초과  2016   7     NaN   nan     nan
# 707   대전  전용면적 102㎡초과  2016   8     NaN   nan     nan
# 775   대전  전용면적 102㎡초과  2016   9     NaN   nan     nan
# 843   대전  전용면적 102㎡초과  2016  10    4328 4,328  14,282
# 911   대전  전용면적 102㎡초과  2016  11    4328 4,328  14,282
# 979   대전  전용면적 102㎡초과  2016  12    4328 4,328  14,282
# 1047  대전  전용면적 102㎡초과  2017   1    4328 4,328  14,282
# ...

# %%
pre_sale_size_t = pre_sale_size.T
pre_sale_size_t
# Out:
# 지역명                  강원     경기    경남    경북     광주     대구     대전     부산     서울  \
# 규모구분
# 전용면적 102㎡초과       7,997 14,380 9,922 8,907 10,497 12,647 14,883 13,001 22,660
# 전용면적 60㎡이하        7,447 12,913 8,637 7,806  9,042 11,688  8,798 11,177 22,688
# 전용면적 60㎡초과 85㎡이하  7,394 12,273 8,422 7,927  9,563 11,434  9,471 11,699 22,093
# 전용면적 85㎡초과 102㎡이하 8,377 13,155 9,931 8,781  9,296 10,619  9,037 11,737 23,754
#
# 지역명                  세종     울산     인천    전남    전북     제주    충남    충북
# 규모구분
# 전용면적 102㎡초과       9,716  9,974 14,049 7,916 8,104 10,324 8,596 8,174
# 전용면적 60㎡이하        9,324  8,965 11,038 7,082 7,561 14,195 7,899 7,058
# 전용면적 60㎡초과 85㎡이하  9,581 10,563 11,158 7,164 7,123 10,320 7,694 7,224
# 전용면적 85㎡초과 102㎡이하 9,611  8,861 11,368 7,927 8,164 10,709 9,003 8,363

# %%
pre_sale.sample()
# Out:
#      지역명        규모구분    연도   월 분양가격(㎡)  분양가격  평당분양가격
# 2520  인천  전용면적 60㎡이하  2018  11    3437 3,437  11,342

# %%
pre_sale[['지역명', '평당분양가격', '규모구분']].sample(3)
# Out:
#      지역명  평당분양가격               규모구분
# 2776  경북   8,204         전용면적 60㎡이하
# 81    부산  10,022   전용면적 60㎡초과 85㎡이하
# 1370  경기  12,065  전용면적 85㎡초과 102㎡이하

# %%
pre_sale['평당분양가격'].isnull().sum()
# Out:
# 302

# %%
# 결측치 제거
pre_sale['평당분양가격'].dropna(inplace=True, axis=0)  # row기준으로 drop하고 inplace는 바로 적용

# %%
pre_sale['평당분양가격'].isnull().sum()
# Out:
# 0

# %%
pre_sale.shape
# Out:
# (3060, 7)

# %%
pre_sale.dtypes
# Out:
# 지역명         object
# 규모구분        object
# 연도          object
# 월           object
# 분양가격(㎡)     object
# 분양가격       float64
# 평당분양가격     float64
# dtype: object

# %%
pre_sale['평당분양가격'] = pre_sale['평당분양가격'].astype(int)

# %%
pre_sale[pre_sale['평당분양가격'] == 0 ]
# Out:
# Empty DataFrame
# Columns: [지역명, 규모구분, 연도, 월, 분양가격(㎡), 분양가격, 평당분양가격]
# Index: []

# %%
pre_sale['규모구분'].unique()
# Out:
# array(['전용면적 60㎡이하', '전용면적 60㎡초과 85㎡이하', '전용면적 85㎡초과 102㎡이하',
#        '전용면적 102㎡초과'], dtype=object)

# %%
pre_sale_size.sample(3)
# Out:
# 규모구분  전용면적 102㎡초과  전용면적 60㎡이하  전용면적 60㎡초과 85㎡이하  전용면적 85㎡초과 102㎡이하
# 지역명
# 강원          7,997       7,447             7,394              8,377
# 광주         10,497       9,042             9,563              9,296
# 대구         12,647      11,688            11,434             10,619

# %%
pre_sale[['지역명', '평당분양가격']].boxplot(by=['지역명'], figsize=(18,6))  # 지역별 평균 평당분양가격

# %%
pre_sale[['연도', '지역명', '평당분양가격']].boxplot(by=['연도'], figsize=(18,6))  # 연도별 평균 평당분양가격

# %%
pre_sale[['연도', '지역명', '평당분양가격']].boxplot(by=['지역명', '연도'], figsize=(18,6), rot=60)

# %%
pre_sale_seoul = pre_sale[pre_sale['지역명'] == '서울']
pre_sale_seoul.head()
# Out:
#    지역명               규모구분    연도   월 분양가격(㎡)  분양가격  평당분양가격
# 0   서울         전용면적 60㎡이하  2015  10    5652 5,652  18,651
# 1   서울   전용면적 60㎡초과 85㎡이하  2015  10    5882 5,882  19,410
# 2   서울  전용면적 85㎡초과 102㎡이하  2015  10    5721 5,721  18,879
# 3   서울        전용면적 102㎡초과  2015  10    5879 5,879  19,400
# 68  서울         전용면적 60㎡이하  2015  11    6320 6,320  20,856

# %%
pre_sale_seoul[['연도', '규모구분', '평당분양가격']].boxplot(by=['연도', '규모구분'], figsize=(18,6), rot=45)

# %%
pre_sale_jeju = pre_sale[pre_sale['지역명'] == '제주']
pre_sale_jeju.head()
# Out:
#     지역명               규모구분    연도   월 분양가격(㎡)  분양가격  평당분양가격
# 64   제주         전용면적 60㎡이하  2015  10           nan     nan
# 65   제주   전용면적 60㎡초과 85㎡이하  2015  10    2225 2,225   7,342
# 66   제주  전용면적 85㎡초과 102㎡이하  2015  10    2583 2,583   8,523
# 67   제주        전용면적 102㎡초과  2015  10    2574 2,574   8,494
# 132  제주         전용면적 60㎡이하  2015  11           nan     nan

# %%
pre_sale_jeju[['연도', '평당분양가격']].boxplot(by=['연도'], figsize=(18,6), rot=45)

# %%
pre_sale_jeju[['연도', '규모구분', '평당분양가격']].boxplot(by=['연도', '규모구분'], figsize=(18,6), rot=45)

# %%
pre_sale_jeju.isnull().sum()
# Out:
# 지역명         0
# 규모구분        0
# 연도          0
# 월           0
# 분양가격(㎡)    21
# 분양가격       27
# 평당분양가격     27
# dtype: int64

# %% [markdown]
# ## Tidy Data 만들기

# %%
df = pd.read_csv('past_price.csv', encoding='euc-kr', engine='python')
df.shape
# Out:
# (24, 27)

# %%
df
# Out:
#    □ 평균 분양가격 Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0        NaN        NaN         nan         nan         nan         nan
# 1         구분        NaN       2,013       2,014         nan         nan
# 2         시도        시군구          12           1           2           3
# 3         전국        NaN       8,059       8,130       8,195       8,204
# 4         서울        NaN      18,189      17,925      17,925      18,016
# 5      6대광역시         부산       8,111       8,111       9,078       8,965
# 6        NaN         대구       8,080       8,080       8,077       8,101
# 7        NaN         인천      10,204      10,204      10,408      10,408
# 8        NaN         광주       6,098       7,326       7,611       7,346
# 9        NaN         대전       8,321       8,321       8,321       8,341
# 10       NaN         울산       8,090       8,090       8,090       8,153
# 11       NaN        NaN       8,151       8,355       8,597       8,552
# ...

# %%
year = df.iloc[1]
month = df.iloc[2]

# %%
year
# Out:
# □ 평균 분양가격                 구분
# Unnamed: 1               NaN
# Unnamed: 2             2,013
# Unnamed: 3             2,014
# Unnamed: 4               NaN
# Unnamed: 5               NaN
# Unnamed: 6               NaN
# Unnamed: 7               NaN
# Unnamed: 8               NaN
# Unnamed: 9               NaN
# Unnamed: 10              NaN
# Unnamed: 11              NaN
# Unnamed: 12              NaN
# Unnamed: 13              NaN
# Unnamed: 14              NaN
# Unnamed: 15            2,015
# Unnamed: 16              NaN
# Unnamed: 17              NaN
# Unnamed: 18              NaN
# Unnamed: 19              NaN
# Unnamed: 20              NaN
# Unnamed: 21              NaN
# Unnamed: 22              NaN
# Unnamed: 23              NaN
# Unnamed: 24              NaN
# Unnamed: 25              NaN
# Unnamed: 26    (단위: 천원/3.3㎡)
# Name: 1, dtype: object

# %%
month
# Out:
# □ 평균 분양가격         시도
# Unnamed: 1       시군구
# Unnamed: 2        12
# Unnamed: 3         1
# Unnamed: 4         2
# Unnamed: 5         3
# Unnamed: 6         4
# Unnamed: 7         5
# Unnamed: 8         6
# Unnamed: 9         7
# Unnamed: 10        8
# Unnamed: 11        9
# Unnamed: 12       10
# Unnamed: 13       11
# Unnamed: 14       12
# Unnamed: 15        1
# Unnamed: 16        2
# Unnamed: 17        3
# Unnamed: 18        4
# Unnamed: 19        5
# Unnamed: 20        6
# Unnamed: 21        7
# Unnamed: 22        8
# Unnamed: 23        9
# Unnamed: 24      전월비
# Unnamed: 25     전년말비
# Unnamed: 26    전년동월비
# Name: 2, dtype: object

# %%
for i, y in enumerate(year):
    if i > 2 and i < 15:
        year[i] = ' '.join(['2014년', str(int(month[i]))]) + '월'
    elif i >= 15 and i < 24:
        year[i] = ' '.join(['2015년', str(int(month[i]))]) + '월'
    elif i == 2:
        year[i] = ' '.join(['2013년', str(int(month[i]))]) + '월'
    elif i == 1:
        year[i] = '시군구'
year
# Out:
# □ 평균 분양가격               구분
# Unnamed: 1             시군구
# Unnamed: 2       2013년 12월
# Unnamed: 3        2014년 1월
# Unnamed: 4        2014년 2월
# Unnamed: 5        2014년 3월
# Unnamed: 6        2014년 4월
# Unnamed: 7        2014년 5월
# Unnamed: 8        2014년 6월
# Unnamed: 9        2014년 7월
# Unnamed: 10       2014년 8월
# Unnamed: 11       2014년 9월
# Unnamed: 12      2014년 10월
# Unnamed: 13      2014년 11월
# Unnamed: 14      2014년 12월
# Unnamed: 15       2015년 1월
# Unnamed: 16       2015년 2월
# Unnamed: 17       2015년 3월
# Unnamed: 18       2015년 4월
# Unnamed: 19       2015년 5월
# Unnamed: 20       2015년 6월
# Unnamed: 21       2015년 7월
# Unnamed: 22       2015년 8월
# Unnamed: 23       2015년 9월
# Unnamed: 24      2015년 전월비
# Unnamed: 25     2015년 전년말비
# Unnamed: 26    2015년 전년동월비
# Name: 1, dtype: object

# %%
df.columns = year

# %%
df
# Out:
# 1      구분  시군구  2013년 12월  2014년 1월  2014년 2월  2014년 3월  2014년 4월  2014년 5월  \
# 0     NaN  NaN        nan       nan       nan       nan       nan       nan
# 1      구분  NaN      2,013     2,014       nan       nan       nan       nan
# 2      시도  시군구         12         1         2         3         4         5
# 3      전국  NaN      8,059     8,130     8,195     8,204     8,289     8,358
# 4      서울  NaN     18,189    17,925    17,925    18,016    18,098    19,446
# 5   6대광역시   부산      8,111     8,111     9,078     8,965     9,402     9,501
# 6     NaN   대구      8,080     8,080     8,077     8,101     8,267     8,274
# 7     NaN   인천     10,204    10,204    10,408    10,408    10,000     9,844
# 8     NaN   광주      6,098     7,326     7,611     7,346     7,346     7,523
# 9     NaN   대전      8,321     8,321     8,321     8,341     8,341     8,341
# 10    NaN   울산      8,090     8,090     8,090     8,153     8,153     8,153
# ...

# %%
df = df.drop(index=[0,1,2])
df
# Out:
# 1      구분  시군구  2013년 12월  2014년 1월  2014년 2월  2014년 3월  2014년 4월  2014년 5월  \
# 3      전국  NaN      8,059     8,130     8,195     8,204     8,289     8,358
# 4      서울  NaN     18,189    17,925    17,925    18,016    18,098    19,446
# 5   6대광역시   부산      8,111     8,111     9,078     8,965     9,402     9,501
# 6     NaN   대구      8,080     8,080     8,077     8,101     8,267     8,274
# 7     NaN   인천     10,204    10,204    10,408    10,408    10,000     9,844
# 8     NaN   광주      6,098     7,326     7,611     7,346     7,346     7,523
# 9     NaN   대전      8,321     8,321     8,321     8,341     8,341     8,341
# 10    NaN   울산      8,090     8,090     8,090     8,153     8,153     8,153
# 11    NaN  NaN      8,151     8,355     8,597     8,552     8,585     8,606
# 12     경기  NaN     10,855    10,855    10,791    10,784    10,876    10,646
# 13    수도권  NaN     13,083    12,995    13,041    13,069    12,991    13,312
# ...

# %%
# 최근 데이터의 컬럼으로 기존 데이터프레임과 합치기 위해 컬럼명 조회
pre_sale.columns
# Out:
# Index(['지역명', '규모구분', '연도', '월', '분양가격(㎡)', '분양가격', '평당분양가격'], dtype='object')

# %%
# 결측치를 빈문자로 채운다
df['구분'] = df['구분'].fillna('')
df['시군구'] = df['시군구'].fillna('')

# %%
df['지역'] = df['구분'] + df['시군구']

# %%
df['지역']
# Out:
# 3          전국
# 4          서울
# 5     6대광역시부산
# 6          대구
# 7          인천
# 8          광주
# 9          대전
# 10         울산
# 11
# 12         경기
# 13        수도권
# 14         세종
# 15       지방강원
# 16         충북
# 17         충남
# 18         전북
# 19         전남
# 20         경북
# 21         경남
# 22         제주
# 23
# Name: 지역, dtype: object

# %%
melt_columns = df.columns.copy()
melt_columns
# Out:
# Index(['구분', '시군구', '2013년 12월', '2014년 1월', '2014년 2월', '2014년 3월',
#        '2014년 4월', '2014년 5월', '2014년 6월', '2014년 7월', '2014년 8월', '2014년 9월',
#        '2014년 10월', '2014년 11월', '2014년 12월', '2015년 1월', '2015년 2월',
#        '2015년 3월', '2015년 4월', '2015년 5월', '2015년 6월', '2015년 7월', '2015년 8월',
#        '2015년 9월', '2015년 전월비', '2015년 전년말비', '2015년 전년동월비', '지역'],
#       dtype='object', name=1)

# %%
pre_sale.sample(3)
# Out:
#      지역명        규모구분    연도   월 분양가격(㎡)  분양가격  평당분양가격
# 48    전북  전용면적 60㎡이하  2015  10    2127 2,127   7,019
# 2816  울산  전용면적 60㎡이하  2019   3     NaN   nan     nan
# 1848  부산  전용면적 60㎡이하  2018   1    3737 3,737  12,332

# %%
df_2013_2015 = pd.melt(df, id_vars=['지역'], value_vars=['2013년 12월', '2014년 1월', '2014년 2월', '2014년 3월',
       '2014년 4월', '2014년 5월', '2014년 6월', '2014년 7월', '2014년 8월',
       '2014년 9월', '2014년 10월', '2014년 11월', '2014년 12월', '2015년 1월',
       '2015년 2월', '2015년 3월', '2015년 4월', '2015년 5월', '2015년 6월',
       '2015년 7월', '2015년 8월', '2015년 9월'])
df_2013_2015.head()
# Out:
#         지역          1  value
# 0       전국  2013년 12월  8,059
# 1       서울  2013년 12월 18,189
# 2  6대광역시부산  2013년 12월  8,111
# 3       대구  2013년 12월  8,080
# 4       인천  2013년 12월 10,204

# %%
df_2013_2015.columns = ['지역', '기간', '분양가']
df_2013_2015.head()
# Out:
#         지역         기간    분양가
# 0       전국  2013년 12월  8,059
# 1       서울  2013년 12월 18,189
# 2  6대광역시부산  2013년 12월  8,111
# 3       대구  2013년 12월  8,080
# 4       인천  2013년 12월 10,204

# %%
df_2013_2015['연도'] = df_2013_2015['기간'].apply(lambda year_month : year_month.split('년')[0])
df_2013_2015['월'] = df_2013_2015['기간'].apply(lambda year_month : re.sub('월', '', year_month.split('년')[1]).strip())
df_2013_2015.head()
# Out:
#         지역         기간    분양가    연도   월
# 0       전국  2013년 12월  8,059  2013  12
# 1       서울  2013년 12월 18,189  2013  12
# 2  6대광역시부산  2013년 12월  8,111  2013  12
# 3       대구  2013년 12월  8,080  2013  12
# 4       인천  2013년 12월 10,204  2013  12

# %%
df_2013_2015['지역'].value_counts()
# Out:
#            44
# 대전         22
# 지방강원       22
# 울산         22
# 서울         22
# 대구         22
# 수도권        22
# 인천         22
# 세종         22
# 6대광역시부산    22
# 전남         22
# 제주         22
# 충북         22
# 경기         22
# 전북         22
# 광주         22
# 경북         22
# 충남         22
# 전국         22
# 경남         22
# Name: 지역, dtype: int64

# %%
df_2013_2015['지역'] = df_2013_2015['지역'].replace('6대광역시부산','부산')
df_2013_2015['지역'] = df_2013_2015['지역'].replace('지방강원','강원')
df_2013_2015['지역'].value_counts()
# Out:
#        44
# 대전     22
# 울산     22
# 서울     22
# 대구     22
# 수도권    22
# 인천     22
# 세종     22
# 경남     22
# 제주     22
# 전남     22
# 충북     22
# 경기     22
# 전북     22
# 광주     22
# 경북     22
# 충남     22
# 강원     22
# 전국     22
# 부산     22
# Name: 지역, dtype: int64

# %%
df_2013_2015.describe()
# Out:
#          분양가
# count    462
# mean   8,611
# std    2,868
# min    5,609
# 25%    6,754
# 50%    8,067
# 75%    8,980
# max   20,670

# %%
df_2013_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 462 entries, 0 to 461
# Data columns (total 5 columns):
# 지역     462 non-null object
# 기간     462 non-null object
# 분양가    462 non-null float64
# 연도     462 non-null object
# 월      462 non-null object
# dtypes: float64(1), object(4)
# memory usage: 18.1+ KB

# %%
# df_2013_2015['분양가격'] = df_2013_2015['분양가'].str.replace(',', '').astype(int)

# %%
plt.figure(figsize=(18,6))
sns.boxplot(data=df_2013_2015, x='지역', y='분양가', hue='연도')

# %%
plt.figure(figsize=(18,6))
sns.barplot(data=df_2013_2015, x='지역', y='분양가', hue='연도')

# %%
df_2015_2018 = pre_sale.loc[pre_sale['규모구분'] == '전용면적 102㎡초과']
print(df_2015_2018.shape)
df_2015_2018.head()
# Out:
# (765, 7)
#    지역명         규모구분    연도   월 분양가격(㎡)  분양가격  평당분양가격
# 3   서울  전용면적 102㎡초과  2015  10    5879 5,879  19,400
# 7   인천  전용면적 102㎡초과  2015  10    3408 3,408  11,246
# 11  경기  전용면적 102㎡초과  2015  10    3680 3,680  12,144
# 15  부산  전용면적 102㎡초과  2015  10    3500 3,500  11,550
# 19  대구  전용면적 102㎡초과  2015  10    2598 2,598   8,573

# %%
df_2013_2015.isnull().shape  # 왜 sum으로하면 안나오지???
# Out:
# (462, 5)

# %%
df_2013_2015.shape
# Out:
# (462, 5)

# %%
df_2015_2018.columns
# Out:
# Index(['지역명', '규모구분', '연도', '월', '분양가격(㎡)', '분양가격', '평당분양가격'], dtype='object')

# %%
df_2013_2015_prepare = df_2013_2015[['지역','연도','월','분양가']]
df_2013_2015_prepare.head()
# Out:
#    지역    연도   월    분양가
# 0  전국  2013  12  8,059
# 1  서울  2013  12 18,189
# 2  부산  2013  12  8,111
# 3  대구  2013  12  8,080
# 4  인천  2013  12 10,204

# %%
df_2013_2015_prepare.columns = ['지역명', '연도', '월', '평당분양가격']

# %%
df_2015_2018.columns
# Out:
# Index(['지역명', '규모구분', '연도', '월', '분양가격(㎡)', '분양가격', '평당분양가격'], dtype='object')

# %%
df_2015_2018_prepare = df_2015_2018[['지역명', '연도', '월', '평당분양가격']]
df_2015_2018_prepare.head()
# Out:
#    지역명    연도   월  평당분양가격
# 3   서울  2015  10  19,400
# 7   인천  2015  10  11,246
# 11  경기  2015  10  12,144
# 15  부산  2015  10  11,550
# 19  대구  2015  10   8,573

# %%
df_2015_2018_prepare.describe()
# Out:
#        평당분양가격
# count     686
# mean   11,206
# std     3,989
# min     7,055
# 25%     8,546
# 50%     9,686
# 75%    13,348
# max    27,819

# %%
df_2013_2018 = pd.concat([df_2013_2015_prepare, df_2015_2018_prepare])
df_2013_2018.shape
# Out:
# (1227, 4)

# %%
df_2013_2018.head()
# Out:
#   지역명    연도   월  평당분양가격
# 0  전국  2013  12   8,059
# 1  서울  2013  12  18,189
# 2  부산  2013  12   8,111
# 3  대구  2013  12   8,080
# 4  인천  2013  12  10,204

# %%
df_2013_2018.tail()
# Out:
#      지역명    연도  월  평당분양가격
# 3043  전북  2019  6   8,692
# 3047  전남  2019  6   9,507
# 3051  경북  2019  6  10,150
# 3055  경남  2019  6  14,199
# 3059  제주  2019  6  10,787

# %%
df_2013_2015_region= df_2013_2015_prepare['지역명'].unique()
df_2013_2015_region
# Out:
# array(['전국', '서울', '부산', '대구', '인천', '광주', '대전', '울산', '', '경기', '수도권',
#        '세종', '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주'], dtype=object)

# %%
df_2015_2018_region = df_2015_2018_prepare['지역명'].unique()
df_2015_2018_region
# Out:
# array(['서울', '인천', '경기', '부산', '대구', '광주', '대전', '울산', '세종', '강원', '충북',
#        '충남', '전북', '전남', '경북', '경남', '제주'], dtype=object)

# %%
exclude_region = [region for region in df_2013_2015_region if not region in df_2015_2018_region] 
exclude_region
# Out:
# ['전국', '', '수도권']

# %%
df_2013_2018.shape
# Out:
# (1227, 4)

# %%
df_2013_2018.loc[df_2013_2018['지역명'].str.match('전국|수도권')].head()
# Out:
#     지역명    연도   월  평당분양가격
# 0    전국  2013  12   8,059
# 10  수도권  2013  12  13,083
# 21   전국  2014   1   8,130
# 31  수도권  2014   1  12,995
# 42   전국  2014   2   8,195

# %%
df_2013_2018.drop(df_2013_2018.loc[df_2013_2018['지역명'].str.match('전국|수도권')].index, axis=0, inplace=True)
df_2013_2018.drop(df_2013_2018.loc[df_2013_2018['지역명'] == ''].index, axis=0, inplace=True)

# %%
df_2013_2018.shape
# Out:
# (1118, 4)

# %%
df_year_mean = df_2013_2018.groupby(['연도'])['평당분양가격'].mean()
df_year_mean
# Out:
# 연도
# 2013    8,059
# 2014    8,362
# 2015    8,783
# 2016   10,462
# 2017   11,334
# 2018   11,445
# 2019   12,878
# Name: 평당분양가격, dtype: float64

# %%
df_year_mean.plot.bar(rot=0)

# %%
sns.barplot(data=df_2013_2018, x='연도', y='평당분양가격')

# %%
df_2013_2018[['연도','지역명','평당분양가격']].boxplot(by=['연도'], figsize=(12,6))

# %%
df_2013_2018_jeju = df_2013_2018.loc[df_2013_2018['지역명']=='제주']
df_2013_2018_jeju[['연도','지역명','평당분양가격']].boxplot(by=['연도'], figsize=(12,6))

# %%
df_2013_2018_jeju['연도'].value_counts()
# Out:
# 2018    12
# 2017    12
# 2015    12
# 2014    12
# 2016    11
# 2019     6
# 2013     1
# Name: 연도, dtype: int64
