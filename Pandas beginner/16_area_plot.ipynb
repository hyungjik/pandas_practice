# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline

# 한글폰트 사용시 그래프에서 마이너스 폰트 꺠지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df.head()
# Out:
#           a         b         c         d
# 0  0.571584  0.912264  0.318606  0.074087
# 1  0.142864  0.571553  0.447379  0.138516
# 2  0.849641  0.934892  0.428714  0.677677
# 3  0.341181  0.070117  0.189778  0.073351
# 4  0.203550  0.087365  0.615645  0.949282

# %%
df.plot()

# %%
df.plot.area(stacked=False, grid=True)

# %%
df.plot.area(grid=True)  # 기본적으로 stack이 True
