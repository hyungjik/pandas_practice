# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline

# 한글폰트 사용시 그래프에서 마이너스 폰트 꺠지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])
df['b'] = df['b'] + np.arange(1000)  # 각각의 인덱스 값을 더해줌
df.head()
# Out:
#           a         b
# 0 -0.417874 -0.722663
# 1 -1.315661  2.247835
# 2  0.242611  1.704346
# 3  0.559439  1.658603
# 4 -0.609326  3.932959

# %%
df.tail()
# Out:
#             a           b
# 995 -2.636624  993.913320
# 996  1.479282  997.016168
# 997 -1.293800  996.851766
# 998 -0.893603  999.643080
# 999 -1.735620  997.826616

# %%
df.plot.scatter(x='a', y='b', s=10)

# %%
df.plot.hexbin(x='a', y='b', gridsize=30)  # grid의 크기 조절가능

# %%
df['z'] = np.random.uniform(0, 3, 1000)

# %%
df.plot.hexbin(x='a', y='b', C='z', reduce_C_function=np.max, gridsize=25)
