# %%
import pandas as pd

# %%
import numpy as np

# %%
# %matplotlib inline

# %%
s = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2015', periods=1000))

# %%
s = s.cumsum()
s.plot()

# %%
# window의 size 만큼 값을 이동시킨다.
# 이동평균을 그릴떄 사용한다.
r = s.rolling(window=60)
r.mean()
# Out:
# 2015-01-01          NaN
# 2015-01-02          NaN
# 2015-01-03          NaN
# 2015-01-04          NaN
# 2015-01-05          NaN
# 2015-01-06          NaN
# 2015-01-07          NaN
# 2015-01-08          NaN
# 2015-01-09          NaN
# 2015-01-10          NaN
# 2015-01-11          NaN
# 2015-01-12          NaN
# 2015-01-13          NaN
# 2015-01-14          NaN
# 2015-01-15          NaN
# 2015-01-16          NaN
# 2015-01-17          NaN
# 2015-01-18          NaN
# 2015-01-19          NaN
# 2015-01-20          NaN
# 2015-01-21          NaN
# 2015-01-22          NaN
# 2015-01-23          NaN
# 2015-01-24          NaN
# 2015-01-25          NaN
# 2015-01-26          NaN
# 2015-01-27          NaN
# 2015-01-28          NaN
# 2015-01-29          NaN
# 2015-01-30          NaN
#                 ...
# 2017-08-28   -20.895581
# 2017-08-29   -20.929604
# 2017-08-30   -20.954145
# 2017-08-31   -20.987010
# 2017-09-01   -21.025092
# 2017-09-02   -21.047362
# 2017-09-03   -21.072344
# 2017-09-04   -21.115701
# 2017-09-05   -21.191868
# 2017-09-06   -21.230673
# 2017-09-07   -21.236897
# 2017-09-08   -21.200118
# 2017-09-09   -21.115016
# 2017-09-10   -21.004782
# 2017-09-11   -20.882115
# 2017-09-12   -20.787825
# 2017-09-13   -20.681666
# 2017-09-14   -20.606961
# 2017-09-15   -20.556727
# 2017-09-16   -20.515443
# 2017-09-17   -20.496220
# 2017-09-18   -20.460510
# 2017-09-19   -20.407412
# 2017-09-20   -20.350120
# 2017-09-21   -20.279428
# 2017-09-22   -20.232241
# 2017-09-23   -20.162273
# 2017-09-24   -20.099033
# 2017-09-25   -20.024835
# 2017-09-26   -19.970987
# Freq: D, Length: 1000, dtype: float64

# %%
s.plot(style='k--')
r.mean().plot(style='k--')

# %%
df = pd.DataFrame(np.random.randn(1000, 4),
                  index=pd.date_range('1/1/2015', periods=1000),
                  columns=['A', 'B', 'C', 'D'])

# %%
df = df.cumsum()
df.plot()
df.rolling(window=60).sum().plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000024346A9E470>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000024346AC8D68>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000024346AF7208>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000024346B23668>],
#       dtype=object)

# %%
df.rolling(window=len(df), min_periods=1).mean().plot()

# %%
df.expanding(min_periods=1).mean().plot()

# %%
df.expanding?

# %%
dfe = pd.DataFrame({'B': [0, 1, 2, np.nan, 4]})
dfe.plot()

# %%
dfe.expanding(2).mean().plot()
