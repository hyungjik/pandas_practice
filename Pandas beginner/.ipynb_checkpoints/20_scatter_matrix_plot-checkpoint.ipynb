# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline

# 한글폰트 사용시 그래프에서 마이너스 폰트 꺠지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %%
from pandas.plotting import scatter_matrix

# %%
df = pd.DataFrame(np.random.randn(1000, 4), columns=['a', 'b', 'c', 'd'])

# %%
df.head()
# Out:
#           a         b         c         d
# 0  0.140565  0.478146 -2.815139 -0.814363
# 1 -1.356117  0.241736  0.991010 -0.851735
# 2  0.489762 -1.398047 -0.369581 -1.001220
# 3 -0.444178  0.946222 -0.987675 -0.429571
# 4  2.733099 -0.517320 -1.010472  0.470997

# %%
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000022CA88A3208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022CA8B3A5C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022CA8B61B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022CA8B910B8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022CA8BB8630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022CA8BDFBA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022CA8C0F160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022CA8C36710>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022CA8C36748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022CA8C90208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022CA8CB6780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022CA8CDECF8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022CA8D0E2B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022CA8D33828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022CA8D5EDA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022CA8D8F358>]],
#       dtype=object)
